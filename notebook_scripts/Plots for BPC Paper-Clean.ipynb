# %%
from util.bpc_util import *

# %%
import matplotlib
matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['text.latex.unicode'] = True
# Out:
# /home/hao/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: MatplotlibDeprecationWarning:
# The text.latex.unicode rcparam was deprecated in Matplotlib 3.0 and will be removed in 3.2.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plt.rcParams['figure.figsize'] = (7,5)

# %%
# %load_ext autoreload

# %%
# %autoreload

# %% [markdown]
# # Synthetic Dataset
#
# We run the tests on the synthetic dataset, with the following settings:
#
# * Normalized Laplacian (i.e. $\chi_k$ are now normalized by degree matrix $D$)
# * ...

# %% [markdown]
# ## Regime 1
# $$\epsilon = \tau^2, \gamma = \tau^{\alpha}$$
#
# This corresponds to ``little_oh = False``

# %%
rand = False
Ns = [100,100,100]
fs = 5
density_= 0.8
normalized = True
little_oh = False
_save = False

norm_s = 'n'
if not normalized:
    norm_s = 'u'
param_str = 'rand_%d_Ns_%d_%d_%d_fs_%d_L_%s_lo_%d' % (int(rand), Ns[0], Ns[1], Ns[2], fs, norm_s, int(little_oh))
print(param_str)


# Get the overall setup, including ground truth u and separated graph W_0
Ns, u, B, labeled, draws, W_0 = syn_overall_setup(rand, Ns, fs, normalized, density_)


n = 20
T   = np.power(0.6, range(5, n+5))
ALPHAS = [0.5, 1, 1.5, 2, 2.5, 3.]
TRC, TRCBC, BIAS = syn_run_test(T, ALPHAS, Ns, B, labeled, u, W_0, little_oh=little_oh) 

syn_plot_data(T, TRC, ALPHAS, param_str, title_= r'$\mathrm{Tr}(C^*)$', \
          val_str='TRC', save=_save, Jval=4, little_oh=little_oh)
syn_plot_data(T, TRCBC, ALPHAS, param_str, title_= r'$\frac{1}{\gamma^2}\mathrm{Tr}(C^*BC^*)$', \
          val_str='TRCBC', save=_save, Jval=4, little_oh=little_oh)
syn_plot_data(T, BIAS, ALPHAS, param_str, title_= r'$|C^*C_{\tau, \epsilon}^{-1}\mathbf{v}|^2$', \
          val_str='BIAS', save=_save, Jval=6, little_oh=little_oh)
# Out:
# rand_0_Ns_100_100_100_fs_5_L_n_lo_0
# Line fitting for TRC
# The slope for alpha = 0.5 is : 0.9884
# The slope for alpha = 1.0 is : 1.9998
# The slope for alpha = 1.5 is : 3.0000
# The slope for alpha = 2.0 is : 4.0000
# The slope for alpha = 2.5 is : 5.0000
# The slope for alpha = 3.0 is : 6.0000
# Line fitting for TRCBC
# The slope for alpha = 0.5 is : 0.9147
# The slope for alpha = 1.0 is : 1.9984
# The slope for alpha = 1.5 is : 3.0000
# The slope for alpha = 2.0 is : 4.0000
# The slope for alpha = 2.5 is : 5.0000
# The slope for alpha = 3.0 is : 6.0000
# Line fitting for BIAS
# The slope for alpha = 0.5 is : 1.9454
# The slope for alpha = 1.0 is : 4.0004
# The slope for alpha = 1.5 is : 4.5359
# The slope for alpha = 2.0 is : 4.0252
# The slope for alpha = 2.5 is : 4.0208
# The slope for alpha = 3.0 is : 4.0208

# %% [markdown]
# ## Regime 2
# $$\epsilon = \tau^3, \gamma = \tau^{\alpha}$$
#
# This corresponds to ``little_oh = True``

# %%
rand = False
Ns = [100,100,100]
fs = 5
density_= 0.8
normalized = True
little_oh = True
_save = False

norm_s = 'n'
if not normalized:
    norm_s = 'u'
param_str = 'rand_%d_Ns_%d_%d_%d_fs_%d_L_%s_lo_%d' % (int(rand), Ns[0], Ns[1], Ns[2], fs, norm_s, int(little_oh))
print(param_str)


# Get the overall setup, including ground truth u and separated graph W_0
Ns, u, B, labeled, draws, W_0 = syn_overall_setup(rand, Ns, fs, normalized, density_)


n = 20
T   = np.power(0.6, range(5, n+5))
ALPHAS = [0.5, 1, 1.5, 2, 2.5, 3.]
TRC, TRCBC, BIAS = syn_run_test(T, ALPHAS, Ns, B, labeled, u, W_0, little_oh=little_oh) 

syn_plot_data(T, TRC, ALPHAS, param_str, title_= r'$\mathrm{Tr}(C^*)$', \
          val_str='TRC', save=_save, Jval=4, little_oh=little_oh)
syn_plot_data(T, TRCBC, ALPHAS, param_str, title_= r'$\frac{1}{\gamma^2}\mathrm{Tr}(C^*BC^*)$', \
          val_str='TRCBC', save=_save, Jval=4, little_oh=little_oh)
syn_plot_data(T, BIAS, ALPHAS, param_str, title_= r'$|C^*C_{\tau, \epsilon}^{-1}\mathbf{v}|^2$', \
          val_str='BIAS', save=_save, Jval=6, little_oh=little_oh)

# %% [markdown]
# # Epsilon = 0 Case

# %%
rand = False
Ns = [100,100,100]
fs = 5
density_= 0.8
normalized = True
_save = False

norm_s = 'n'
if not normalized:
    norm_s = 'u'
param_str = 'rand_%d_Ns_%d_%d_%d_fs_%d_L_%s_zero' % (int(rand), Ns[0], Ns[1], Ns[2], fs, norm_s)
print(param_str)


# Get the overall setup, including ground truth u and separated graph W_0
Ns, u, B, labeled, draws, W_0 = syn_overall_setup(rand, Ns, fs, normalized, density_)


n = 20
T   = np.power(0.6, range(5, n+5))
ALPHAS = [0.5, 1, 1.5, 2, 2.5, 3.]
TRC, TRCBC, BIAS = syn_run_test0(T, ALPHAS, Ns, B, labeled, u, W_0)

# %%
syn_plot_data(T, TRC, ALPHAS, param_str, title_= r'$\mathrm{Tr}(C^*)$', \
          val_str='TRC', save=_save, Jval=1)
syn_plot_data(T, TRCBC, ALPHAS, param_str, title_= r'$\frac{1}{\gamma^2}\mathrm{Tr}(C^*BC^*)$', \
          val_str='TRCBC', save=_save, Jval=1)
syn_plot_data(T, BIAS, ALPHAS, param_str, title_= r'$|C^*C_{\tau, \epsilon}^{-1}\mathbf{v}|^2$', \
          val_str='BIAS', save=_save, Jval=1)

# %% [markdown]
# ### Observations
#
# The slope in the BIAS plots do follow the expected curve of $\tau^{4\alpha}$.

# %% [markdown]
# # Voting Records Code

# %%
# %autoreload

# %%
sup_percent = 0.1
n = 10
T   = np.power(0.6, range(5, n+5))
ALPHAS = [0.5, 1, 1.5, 2, 2.5, 3.]
SIGMAS = [0.25*i for i in range(1, 10)]

TRC, TRCBC, BIAS, EVALS = voting_run_test(SIGMAS, T, ALPHAS, rand=True, sup_percent=sup_percent, normalized=True, k_nn=400)
# Out:
# Spectral gap evals are: [0.031074228267197412, 0.10972285934660031, 0.20147293430630597, 0.28654915788895274, 0.3591497728735893, 0.41943830426201445, 0.4692838055483668, 0.5107024371223984, 0.5454174351360714]

# %%
plt.plot(SIGMAS, EVALS)

# %% [markdown]
# - $\mathrm{Tr}(C^\ast)$ goes to zero regardless of $\epsilon$
# - The bias is affected by the $\epsilon$ (probably $\epsilon^\alpha, \epsilon$)
# - We assume the groundtruth $u^\dagger \in \mathrm{span}(\bar{\chi}_0,\cdots)$ ...
# does that mean we should do so for any regression model rather than using $\chi_i$'s.

# %%
_save = False
param_str = 'VotingRecords'

for i,sigma in enumerate(SIGMAS):
    print("sigma = %1.3f" % sigma)
    voting_plot_data(T, TRC[:,:, i], ALPHAS, param_str, title_= r'$\mathrm{Tr}(C^*)$', \
              val_str='TRC', save=_save)
    voting_plot_data(T, TRCBC[:,:, i], ALPHAS, param_str, title_= r'$\frac{1}{\gamma^2}\mathrm{Tr}(C^*BC^*)$', \
              val_str='TRCBC', save=_save)
    voting_plot_data(T, BIAS[:,:,i], ALPHAS, param_str, title_= r'$|C^*C_{\tau, \epsilon}^{-1}\mathbf{v}|^2$', \
              val_str='BIAS', save=_save)
# Out:
# sigma = 0.250
# sigma = 0.500
# sigma = 0.750
# sigma = 1.000
# sigma = 1.250
# sigma = 1.500
# sigma = 1.750
# sigma = 2.000
# sigma = 2.250

# %%
_save = False
param_str = 'VotingRecords'

for i,alpha in enumerate(ALPHAS):
    print("alpha = %1.3f" % alpha)
    voting_plot_data2(T, TRC[i,:,:], SIGMAS, param_str, title_= r'$\mathrm{Tr}(C^*)$', \
              val_str='TRC', save=_save)
    voting_plot_data2(T, TRCBC[i,:,:], SIGMAS, param_str, title_= r'$\frac{1}{\gamma^2}\mathrm{Tr}(C^*BC^*)$', \
              val_str='TRCBC', save=_save)
    voting_plot_data2(T, BIAS[i,:,:], SIGMAS, param_str, title_= r'$|C^*C_{\tau, \epsilon}^{-1}\mathbf{v}|^2$', \
              val_str='BIAS', save=_save)
# Out:
# alpha = 0.500
# alpha = 1.000
# alpha = 1.500
# alpha = 2.000
# alpha = 2.500
# alpha = 3.000

# %% [markdown]
# ### Observations
#
# The BIAS plot shows that we are limited by the value of $\epsilon$ which is constant for each value of the kernel width, $\sigma$.
