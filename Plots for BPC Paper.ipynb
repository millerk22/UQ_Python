# %%
from util.bpc_util_old import *

# %%
import matplotlib
matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['text.latex.unicode'] = True
# Out:
# /Users/Kevin/miniconda3/lib/python3.6/site-packages/matplotlib/__init__.py:846: MatplotlibDeprecationWarning:
# The text.latex.unicode rcparam was deprecated in Matplotlib 2.2 and will be removed in 3.1.
#   "2.2", name=key, obj_type="rcparam", addendum=addendum)

# %%
plt.rcParams['figure.figsize'] = (7,5)

# %% [markdown]
# # Normalized Laplacian Tests
#
# Note here we had to make some changes to the code to be able to get $\mathbf{u}$ in the span of the correct $\chi_k$'s

# %% [markdown]
# ## Regime 1
#
# $$\epsilon = \tau^2, \gamma = \tau^{\alpha}$$
#
# This corresponds to ``little_oh = False``

# %%
rand = False
Ns = [100,100,100]
fs = 5
little_oh = False

Ns, u, B, labeled, H, draws, W_0 = overall_setup_norm(rand, Ns, fs)
param_str = 'rand_%d_Ns_%d_%d_%d_fs_%d_lo_%d' % (int(rand), Ns[0], Ns[1], Ns[2], fs, int(little_oh))

n = 20
T   = np.power(0.6, range(5, n+5))
ALPHAS = [0.5, 1, 1.5, 2, 2.5, 3.]
TRC, TRCBC, normC, normC_tau_inv_u, normC_tau_inv_u_p1, normC_tau_inv_u_p2, BIAS = run_test_norm(T, 
                                                            ALPHAS, Ns, B, labeled, u, W_0, little_oh=False)    

_save = False
print(param_str)
plot_trC(T, TRC, ALPHAS, param_str, save=_save, Jval=6)
plot_trCBC(T, TRCBC, ALPHAS, param_str, save=_save, Jval=8)
plot_data(T, BIAS, ALPHAS, param_str, title_= r'$|C^*C_{\tau, \epsilon}^{-1}\mathbf{v}|$', save=False, Jval=-1)
plot_data(T, normC*normC_tau_inv_u, ALPHAS, param_str,  title_=r'$\|C^*\|_2|C_{\tau, \epsilon}^{-1}\mathbf{v}|$', save=False, Jval=-1)
plot_data(T, TRC*normC_tau_inv_u, ALPHAS, param_str,  title_=r'$\mathrm{Tr}(C^*)|C_{\tau, \epsilon}^{-1}\mathbf{v}|$', save=False, Jval=-1)
plot_data(T, normC, ALPHAS, param_str, title_=r'$\|C^*\|_2$', save=False, Jval=-1)
plot_data(T, normC_tau_inv_u, ALPHAS, param_str,  title_=r'$|C_{\tau, \epsilon}^{-1}\mathbf{v}|$', save=False, Jval=-1)
plot_data(T, normC_tau_inv_u_p1+normC_tau_inv_u_p2, ALPHAS, param_str,  
          title_=r'$|C_{\tau, \epsilon}^{-1}P_\epsilon\mathbf{v}| + |C_{\tau, \epsilon}^{-1}(I - P_\epsilon)\mathbf{v}|$', save=False, Jval=-1)
plot_data(T, normC_tau_inv_u_p1, ALPHAS, param_str,  
          title_=r'$|C_{\tau, \epsilon}^{-1}P_\epsilon\mathbf{v}|$', save=False, Jval=-1)
plot_data(T, normC_tau_inv_u_p2, ALPHAS, param_str,  
          title_=r'$|C_{\tau, \epsilon}^{-1}(I - P_\epsilon)\mathbf{v}|$', save=False, Jval=-1)
# Out:
# 1.0
# rand_0_Ns_100_100_100_fs_5_lo_0
# Line fitting for Tr(C)
# The slope for alpha = 0.5 is : 0.9941
# The slope for alpha = 1.0 is : 2.0000
# The slope for alpha = 1.5 is : 3.0000
# The slope for alpha = 2.0 is : 4.0000
# The slope for alpha = 2.5 is : 5.0000
# The slope for alpha = 3.0 is : 6.0000
# Line fitting for Tr(CBC)/gamma^2
# The slope for alpha = 0.5 is : 0.9585
# The slope for alpha = 1.0 is : 1.9998
# The slope for alpha = 1.5 is : 3.0000
# The slope for alpha = 2.0 is : 4.0000
# The slope for alpha = 2.5 is : 5.0000
# The slope for alpha = 3.0 is : 6.0000

# %%
plt.imshow(W_0.toarray())
plt.show()

# %% [markdown]
# # Second Regime
#
# $$\epsilon = \tau^3, \gamma = \tau^{\alpha}$$
#
# This corresponds to ``little_oh = True``

# %%
rand = False
Ns = [100,100,100]
fs = 5
little_oh = True

Ns, u, B, labeled, H, draws, W_0 = overall_setup_norm(rand, Ns, fs)
param_str = 'rand_%d_Ns_%d_%d_%d_fs_%d_lo_%d' % (int(rand), Ns[0], Ns[1], Ns[2], fs, int(little_oh))

n = 20
T   = np.power(0.6, range(5, n+5))
ALPHAS = [0.5, 1, 1.5, 2, 2.5, 3.]
TRC, TRCBC, normC, normC_tau_inv_u, normC_tau_inv_u_p1, normC_tau_inv_u_p2, BIAS = run_test_norm(T, 
                                                            ALPHAS, Ns, B, labeled, u, W_0, little_oh=False)    

_save = False
print(param_str)
plot_trC(T, TRC, ALPHAS, param_str, save=_save, Jval=6)
plot_trCBC(T, TRCBC, ALPHAS, param_str, save=_save, Jval=8)
plot_data(T, BIAS, ALPHAS, param_str, title_= r'$|C^*C_{\tau, \epsilon}^{-1}\mathbf{v}|$', save=False, Jval=-1)
plot_data(T, normC*normC_tau_inv_u, ALPHAS, param_str,  title_=r'$\|C^*\|_2|C_{\tau, \epsilon}^{-1}\mathbf{v}|$', save=False, Jval=-1)
plot_data(T, TRC*normC_tau_inv_u, ALPHAS, param_str,  title_=r'$\mathrm{Tr}(C^*)|C_{\tau, \epsilon}^{-1}\mathbf{v}|$', save=False, Jval=-1)
plot_data(T, normC, ALPHAS, param_str, title_=r'$\|C^*\|_2$', save=False, Jval=-1)
plot_data(T, normC_tau_inv_u, ALPHAS, param_str,  title_=r'$|C_{\tau, \epsilon}^{-1}\mathbf{v}|$', save=False, Jval=-1)
plot_data(T, normC_tau_inv_u_p1+normC_tau_inv_u_p2, ALPHAS, param_str,  
          title_=r'$|C_{\tau, \epsilon}^{-1}P_\epsilon\mathbf{v}| + |C_{\tau, \epsilon}^{-1}(I - P_\epsilon)\mathbf{v}|$', save=False, Jval=-1)
plot_data(T, normC_tau_inv_u_p1, ALPHAS, param_str,  
          title_=r'$|C_{\tau, \epsilon}^{-1}P_\epsilon\mathbf{v}|$', save=False, Jval=-1)
plot_data(T, normC_tau_inv_u_p2, ALPHAS, param_str,  
          title_=r'$|C_{\tau, \epsilon}^{-1}(I - P_\epsilon)\mathbf{v}|$', save=False, Jval=-1)
# Out:
# 1.0
# rand_0_Ns_100_100_100_fs_5_lo_1
# Line fitting for Tr(C)
# The slope for alpha = 0.5 is : 0.9941
# The slope for alpha = 1.0 is : 2.0000
# The slope for alpha = 1.5 is : 3.0000
# The slope for alpha = 2.0 is : 4.0000
# The slope for alpha = 2.5 is : 5.0000
# The slope for alpha = 3.0 is : 6.0000
# Line fitting for Tr(CBC)/gamma^2
# The slope for alpha = 0.5 is : 0.9585
# The slope for alpha = 1.0 is : 1.9998
# The slope for alpha = 1.5 is : 3.0000
# The slope for alpha = 2.0 is : 4.0000
# The slope for alpha = 2.5 is : 5.0000
# The slope for alpha = 3.0 is : 6.0000

# %% [markdown]
# # Unnormalized Laplacian Tests
#
# This just uses the previous code that was used for previous plots, using that $\mathbf{u}$ was in the span of constant functions on the different clusters

# %% [markdown]
# # First Regime
#
# $$\epsilon = \tau^2, \gamma = \tau^{\alpha}$$
#
# This corresponds to ``little_oh = False``

# %%
rand = False
Ns = [100,100,100]
fs = 5
little_oh = False

Ns, u, B, labeled, H, draws = overall_setup()
param_str = 'rand_%d_Ns_%d_%d_%d_fs_%d_lo_%d' % (int(rand), Ns[0], Ns[1], Ns[2], fs, int(little_oh))

n = 20
T   = np.power(0.6, range(5, n+5))
ALPHAS = [0.5, 1, 1.5, 2, 2.5, 3.]
TRC, TRCBC, normC, normC_tau_inv_u, normC_tau_inv_u_p1, normC_tau_inv_u_p2, BIAS = run_test2(T, 
                                                                    ALPHAS, Ns, B, labeled, u, little_oh=False)    

_save = False
print(param_str)
plot_trC(T, TRC, ALPHAS, param_str, save=_save, Jval=6)
plot_trCBC(T, TRCBC, ALPHAS, param_str, save=_save, Jval=8)

print('Bias')
plot_data(T, BIAS, ALPHAS, param_str, title_= r'$|C^*C_{\tau, \epsilon}^{-1}\mathbf{v}|$', save=False, Jval=-1)
print('normC * normC_tau_inv_u')
plot_data(T, normC*normC_tau_inv_u, ALPHAS, param_str,  title_=r'$\|C^*\|_2|C_{\tau, \epsilon}^{-1}\mathbf{v}|$', save=False, Jval=-1)
print('TRC * normC_tau_inv_u')
plot_data(T, TRC*normC_tau_inv_u, ALPHAS, param_str,  title_=r'$\mathrm{Tr}(C^*)|C_{\tau, \epsilon}^{-1}\mathbf{v}|$', save=False, Jval=-1)
print('NORM of C*')
plot_data(T, normC, ALPHAS, param_str, title_=r'$\|C^*\|_2$', save=False, Jval=-1)
print('NORM of C_tau_inv u')
plot_data(T, normC_tau_inv_u, ALPHAS, param_str,  title_=r'$|C_{\tau, \epsilon}^{-1}\mathbf{v}|$', save=False, Jval=-1)
print('NORM of C_tau_inv u _p1 + C_tau_inv u _p2')
plot_data(T, normC_tau_inv_u_p1+normC_tau_inv_u_p2, ALPHAS, param_str,  
          title_=r'$|C_{\tau, \epsilon}^{-1}P_\epsilon\mathbf{v}| + |C_{\tau, \epsilon}^{-1}(I - P_\epsilon)\mathbf{v}|$', save=False, Jval=-1)
print('NORM of C_tau_inv u _p1')
plot_data(T, normC_tau_inv_u_p1, ALPHAS, param_str,  
          title_=r'$|C_{\tau, \epsilon}^{-1}P_\epsilon\mathbf{v}|$', save=False, Jval=-1)
print('NORM of C_tau_inv u _p2')
plot_data(T, normC_tau_inv_u_p2, ALPHAS, param_str,  
          title_=r'$|C_{\tau, \epsilon}^{-1}(I - P_\epsilon)\mathbf{v}|$', save=False, Jval=-1)

# %% [markdown]
# ## Random initialization for $u$

# %%
rand = True
Ns = [100,100,100]
fs = 5
little_oh = False


Ns, u, B, labeled, H, draws = overall_setup(rand, num_in_each=fs)
param_str = 'rand_%d_Ns_%d_%d_%d_fs_%d_lo_%d' % (int(rand), Ns[0], Ns[1], Ns[2], fs, int(little_oh))

n = 20
T   = np.power(0.6, range(5, n+5))
ALPHAS = [0.5, 1, 1.5, 2, 2.5, 3.]
TRC, TRCBC, normC, normC_tau_inv_u, normC_tau_inv_u_p1, normC_tau_inv_u_p2, BIAS = run_test2(T, 
                                                                    ALPHAS, Ns, B, labeled, u, little_oh=False)    

_save = False
print(param_str)
plot_trC(T, TRC, ALPHAS, param_str, save=_save, Jval=6)
plot_trCBC(T, TRCBC, ALPHAS, param_str, save=_save, Jval=8)

print('Bias')
plot_data(T, BIAS, ALPHAS, param_str, title_= r'$|C^*C_{\tau, \epsilon}^{-1}\mathbf{v}|$', save=False, Jval=-1)
print('normC * normC_tau_inv_u')
plot_data(T, normC*normC_tau_inv_u, ALPHAS, param_str,  title_=r'$\|C^*\|_2|C_{\tau, \epsilon}^{-1}\mathbf{v}|$', save=False, Jval=-1)
print('TRC * normC_tau_inv_u')
plot_data(T, TRC*normC_tau_inv_u, ALPHAS, param_str,  title_=r'$\mathrm{Tr}(C^*)|C_{\tau, \epsilon}^{-1}\mathbf{v}|$', save=False, Jval=-1)
print('NORM of C*')
plot_data(T, normC, ALPHAS, param_str, title_=r'$\|C^*\|_2$', save=False, Jval=-1)
print('NORM of C_tau_inv u')
plot_data(T, normC_tau_inv_u, ALPHAS, param_str,  title_=r'$|C_{\tau, \epsilon}^{-1}\mathbf{v}|$', save=False, Jval=-1)
print('NORM of C_tau_inv u _p1 + C_tau_inv u _p2')
plot_data(T, normC_tau_inv_u_p1+normC_tau_inv_u_p2, ALPHAS, param_str,  
          title_=r'$|C_{\tau, \epsilon}^{-1}P_\epsilon\mathbf{v}| + |C_{\tau, \epsilon}^{-1}(I - P_\epsilon)\mathbf{v}|$', save=False, Jval=-1)
print('NORM of C_tau_inv u _p1')
plot_data(T, normC_tau_inv_u_p1, ALPHAS, param_str,  
          title_=r'$|C_{\tau, \epsilon}^{-1}P_\epsilon\mathbf{v}|$', save=False, Jval=-1)
print('NORM of C_tau_inv u _p2')
plot_data(T, normC_tau_inv_u_p2, ALPHAS, param_str,  
          title_=r'$|C_{\tau, \epsilon}^{-1}(I - P_\epsilon)\mathbf{v}|$', save=False, Jval=-1)

# %% [markdown]
# ## Disproportionate class sizes

# %%
rand = True
fs = 5
Ns = [100,20, 20]
little_oh = False


Ns, u, B, labeled, H, draws = overall_setup(rand, Ns, num_in_each=fs)
param_str = 'rand_%d_Ns_%d_%d_%d_fs_%d_lo_%d' % (int(rand), Ns[0], Ns[1], Ns[2], fs, int(little_oh))

n = 20
T   = np.power(0.6, range(5, n+5))
ALPHAS = [0.5, 1, 1.5, 2, 2.5, 3.]
TRC, TRCBC, normC, normC_tau_inv_u, normC_tau_inv_u_p1, normC_tau_inv_u_p2, BIAS = run_test2(T, 
                                                                    ALPHAS, Ns, B, labeled, u, little_oh=False)    

_save = False
print(param_str)
plot_trC(T, TRC, ALPHAS, param_str, save=_save, Jval=6)
plot_trCBC(T, TRCBC, ALPHAS, param_str, save=_save, Jval=8)

print('Bias')
plot_data(T, BIAS, ALPHAS, param_str, title_= r'$|C^*C_{\tau, \epsilon}^{-1}\mathbf{v}|$', save=False, Jval=-1)
print('normC * normC_tau_inv_u')
plot_data(T, normC*normC_tau_inv_u, ALPHAS, param_str,  title_=r'$\|C^*\|_2|C_{\tau, \epsilon}^{-1}\mathbf{v}|$', save=False, Jval=-1)
print('TRC * normC_tau_inv_u')
plot_data(T, TRC*normC_tau_inv_u, ALPHAS, param_str,  title_=r'$\mathrm{Tr}(C^*)|C_{\tau, \epsilon}^{-1}\mathbf{v}|$', save=False, Jval=-1)
print('NORM of C*')
plot_data(T, normC, ALPHAS, param_str, title_=r'$\|C^*\|_2$', save=False, Jval=-1)
print('NORM of C_tau_inv u')
plot_data(T, normC_tau_inv_u, ALPHAS, param_str,  title_=r'$|C_{\tau, \epsilon}^{-1}\mathbf{v}|$', save=False, Jval=-1)
print('NORM of C_tau_inv u _p1 + C_tau_inv u _p2')
plot_data(T, normC_tau_inv_u_p1+normC_tau_inv_u_p2, ALPHAS, param_str,  
          title_=r'$|C_{\tau, \epsilon}^{-1}P_\epsilon\mathbf{v}| + |C_{\tau, \epsilon}^{-1}(I - P_\epsilon)\mathbf{v}|$', save=False, Jval=-1)
print('NORM of C_tau_inv u _p1')
plot_data(T, normC_tau_inv_u_p1, ALPHAS, param_str,  
          title_=r'$|C_{\tau, \epsilon}^{-1}P_\epsilon\mathbf{v}|$', save=False, Jval=-1)
print('NORM of C_tau_inv u _p2')
plot_data(T, normC_tau_inv_u_p2, ALPHAS, param_str,  
          title_=r'$|C_{\tau, \epsilon}^{-1}(I - P_\epsilon)\mathbf{v}|$', save=False, Jval=-1)

# %% [markdown]
# ## Now only 1 fidelity point

# %%
rand = True
fs = 1
Ns = [100,20, 20]
little_oh = False
Ns, u, B, labeled, H, draws = overall_setup(rand, Ns, num_in_each=fs)
param_str = 'rand_%d_Ns_%d_%d_%d_fs_%d_lo_%d' % (int(rand), Ns[0], Ns[1], Ns[2], fs, int(little_oh))

n = 20
T   = np.power(0.6, range(5, n+5))
ALPHAS = [0.5, 1, 1.5, 2, 2.5, 3.]
TRC, TRCBC = run_test(T, ALPHAS, Ns, B, labeled, little_oh)

# %%
_save = True
print(param_str)
plot_trC(T, TRC, ALPHAS, param_str, save=_save, Jval=8)
plot_trCBC(T, TRCBC, ALPHAS, param_str, save=_save, Jval=12)

# %% [markdown]
# # Second Regime
#
# $$\epsilon = \tau^3, \gamma = \tau^{\alpha}$$
#
# This corresponds to ``little_oh = True``

# %%
rand = False
Ns = [100,100,100]
fs = 5
little_oh = True

Ns, u, B, labeled, H, draws = overall_setup(rand, Ns, fs)
param_str = 'rand_%d_Ns_%d_%d_%d_fs_%d_lo_%d' % (int(rand), Ns[0], Ns[1], Ns[2], fs, int(little_oh))

n = 20
T   = np.power(0.6, range(5, n+5))
ALPHAS = [0.5, 1, 1.5, 2, 2.5, 3.]
TRC, TRCBC = run_test(T, ALPHAS, Ns, B, labeled, little_oh)    

_save = True
print(param_str)
plot_trC(T, TRC, ALPHAS, param_str, save=_save, Jval=6)
plot_trCBC(T, TRCBC, ALPHAS, param_str, save=_save, Jval=8)

# %%
rand = True
Ns = [100,100,100]
fs = 5
little_oh = True

Ns, u, B, labeled, H, draws = overall_setup(rand, Ns, fs)
param_str = 'rand_%d_Ns_%d_%d_%d_fs_%d_lo_%d' % (int(rand), Ns[0], Ns[1], Ns[2], fs, int(little_oh))

n = 20
T   = np.power(0.6, range(5, n+5))
ALPHAS = [0.5, 1, 1.5, 2, 2.5, 3.]
TRC, TRCBC = run_test(T, ALPHAS, Ns, B, labeled, little_oh)    

_save = True
print(param_str)
plot_trC(T, TRC, ALPHAS, param_str, save=_save, Jval=6)
plot_trCBC(T, TRCBC, ALPHAS, param_str, save=_save, Jval=8)

# %%
rand = True
Ns = [100,20,20]
fs = 5
little_oh = True

Ns, u, B, labeled, H, draws = overall_setup(rand, Ns, fs)
param_str = 'rand_%d_Ns_%d_%d_%d_fs_%d_lo_%d' % (int(rand), Ns[0], Ns[1], Ns[2], fs, int(little_oh))

n = 20
T   = np.power(0.6, range(5, n+5))
ALPHAS = [0.5, 1, 1.5, 2, 2.5, 3.]
TRC, TRCBC = run_test(T, ALPHAS, Ns, B, labeled, little_oh)    

_save = True
print(param_str)
plot_trC(T, TRC, ALPHAS, param_str, save=_save, Jval=6)
plot_trCBC(T, TRCBC, ALPHAS, param_str, save=_save, Jval=8)

# %%
rand = True
Ns = [100,20,20]
fs = 1
little_oh = True

Ns, u, B, labeled, H, draws = overall_setup(rand, Ns, fs)
param_str = 'rand_%d_Ns_%d_%d_%d_fs_%d_lo_%d' % (int(rand), Ns[0], Ns[1], Ns[2], fs, int(little_oh))

n = 20
T   = np.power(0.6, range(5, n+5))
ALPHAS = [0.5, 1, 1.5, 2, 2.5, 3.]
TRC, TRCBC = run_test(T, ALPHAS, Ns, B, labeled, little_oh)    

_save = True
print(param_str)
plot_trC(T, TRC, ALPHAS, param_str, save=_save, Jval=6)
plot_trCBC(T, TRCBC, ALPHAS, param_str, save=_save, Jval=12)
